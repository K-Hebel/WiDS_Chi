# %% [markdown]
# # WiDS Competion - Data Exploration
# by Karen H.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data_dict=pd.read_csv("DataDictionaryWiDS2021.csv")
df=pd.read_csv("TrainingWiDS2021.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  encounter_id  hospital_id   age        bmi  elective_surgery  \
# 0           1        214826          118  68.0  22.732803                 0
# 1           2        246060           81  77.0  27.421875                 0
# 2           3        276985          118  25.0  31.952749                 0
# 3           4        262220          118  81.0  22.635548                 1
# 4           5        201746           33  19.0        NaN                 0
#
#    ethnicity gender  height hospital_admit_source  ... h1_pao2fio2ratio_max  \
# 0  Caucasian      M   180.3                 Floor  ...                  NaN
# 1  Caucasian      F   160.0                 Floor  ...                 51.0
# 2  Caucasian      F   172.7  Emergency Department  ...                  NaN
# 3  Caucasian      F   165.1        Operating Room  ...                337.0
# 4  Caucasian      M   188.0                   NaN  ...                  NaN
#
# ...

# %%
data_dict.head()
data_dict
# Out:
#                Category                Variable Name     Unit of Measure  \
# 0            identifier                 encounter_id                None
# 1            identifier                  hospital_id                None
# 2           demographic                          age               Years
# 3           demographic                          bmi  kilograms/metres^2
# 4           demographic             elective_surgery                None
# ..                  ...                          ...                 ...
# 176  APACHE comorbidity            immunosuppression                None
# 177  APACHE comorbidity                     leukemia                None
# 178  APACHE comorbidity                     lymphoma                None
# 179  APACHE comorbidity  solid_tumor_with_metastasis                None
# 180     Target Variable            diabetes_mellitus                None
#
#     Data Type                                        Description Example
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
target_def=data_dict[data_dict['Variable Name']=='diabetes_mellitus']
target_def
# Out:
#             Category      Variable Name Unit of Measure Data Type  \
# 180  Target Variable  diabetes_mellitus            None    binary
#
#                                                                            Description  \
# 180  Whether the patient has been diagnosed with diabetes mellitus, a chronic disease.
#
#     Example
# 180       1

# %% [markdown]
# ## The target is diabetes_mellitus = 1
# ### I'd like to review all the data where the target is equal to 1

# %%
df_yes=df[df.diabetes_mellitus == 1]
df_yes.head()
# Out:
#     Unnamed: 0  encounter_id  hospital_id   age        bmi  elective_surgery  \
# 0            1        214826          118  68.0  22.732803                 0
# 1            2        246060           81  77.0  27.421875                 0
# 5            6        182697           83  67.0  27.555611                 0
# 6            7        195124           83  59.0  57.451002                 0
# 15          16        239271          118  78.0        NaN                 0
#
#     ethnicity gender  height hospital_admit_source      icu_admit_source  \
# 0   Caucasian      M   180.3                 Floor                 Floor
# 1   Caucasian      F   160.0                 Floor                 Floor
# 5   Caucasian      M   190.5          Direct Admit  Accident & Emergency
# 6   Caucasian      F   165.1        Operating Room  Accident & Emergency
# 15  Caucasian      F   160.0  Emergency Department  Accident & Emergency
#
# ...

# %%
#dataframe of patient vital statistics for diabetic patients


#segregate vitals columns from the data_dict
vitals_cols= data_dict[data_dict['Category'].isin(['vitals', 'gas', 'labs blood gas'])]
vitals_cols=list(vitals_cols['Variable Name'].values)
vitals_cols

#create dataframe of only vitals columns

df_vitals = df_yes[vitals_cols]
df_vitals.describe()
# Out:
#        d1_diasbp_invasive_max  d1_diasbp_invasive_min  d1_diasbp_max  \
# count             7686.000000             7686.000000   28107.000000
# mean                76.968774               44.925709      87.947949
# std                 21.447145               12.184029      20.889351
# min                 37.000000                5.000000      46.000000
# 25%                 63.000000               38.000000      73.000000
# 50%                 73.000000               44.000000      85.000000
# 75%                 86.000000               51.000000      99.000000
# max                181.000000               89.000000     165.000000
#
#        d1_diasbp_min  d1_diasbp_noninvasive_max  d1_diasbp_noninvasive_min  \
# count   28107.000000               27769.000000               27769.000000
# mean       48.590031                  88.147827                  48.661061
# std        13.134668                  20.864600                  13.164739
# ...

# %%
#segregate APACHE covariate and APACHE comorbidity columns from the data_dict
APACHE_cols= data_dict[data_dict['Category'].isin(['APACHE covariate', 'APACHE comorbidity'])]
APACHE_cols=list(APACHE_cols['Variable Name'].values)
APACHE_cols

#create dataframe of only APACHE columns

df_APACHE = df_yes[APACHE_cols]
df_APACHE.describe()
# Out:
#        albumin_apache  apache_2_diagnosis  apache_3j_diagnosis  \
# count    11639.000000        27940.000000         28096.000000
# mean         2.854369          186.111095           557.551703
# std          0.654684           87.310559           452.147529
# min          1.200000          101.000000             0.010000
# 25%          2.400000          113.000000           201.010000
# 50%          2.900000          123.000000           501.010000
# 75%          3.300000          302.000000           703.030000
# max          4.600000          308.000000          2201.050000
#
#        apache_post_operative    arf_apache  bilirubin_apache    bun_apache  \
# count           28151.000000  28151.000000      10487.000000  23447.000000
# mean                0.198039      0.062058          1.018866     31.313690
# std                 0.398529      0.241265          1.800553     22.846187
# min                 0.000000      0.000000          0.100000      4.000000
# ...

# %%
df_APACHE.head()
# Out:
#     albumin_apache  apache_2_diagnosis  apache_3j_diagnosis  \
# 0              2.3               113.0               502.01
# 1              NaN               108.0               203.01
# 5              NaN               301.0               403.01
# 6              NaN               108.0               203.01
# 15             NaN               113.0               502.01
#
#     apache_post_operative  arf_apache  bilirubin_apache  bun_apache  \
# 0                       0           0               0.4        31.0
# 1                       0           0               NaN         9.0
# 5                       0           0               NaN        13.0
# 6                       0           0               NaN        18.0
# 15                      0           0               NaN        34.0
#
#     creatinine_apache  fio2_apache  gcs_eyes_apache  gcs_motor_apache  \
# 0                2.51          NaN              3.0               6.0
# ...

# %%
#segregate Demographic covariate columns from the data_dict
demo_cols= data_dict[data_dict['Variable Name'].isin(['gender','height', 'ethnicity', 'age', 'weight'])]
demo_cols=list(demo_cols['Variable Name'].values)
demo_cols

#create dataframe of only APACHE columns

df_demo = df_yes[demo_cols]
df_demo.describe()
# Out:
#                 age        height        weight
# count  27491.000000  27828.000000  27424.000000
# mean      64.564257    169.518772     91.177235
# std       14.460233     10.802548     26.849820
# min        0.000000    137.200000     38.600000
# 25%       56.000000    162.500000     72.300000
# 50%       66.000000    170.000000     87.000000
# 75%       75.000000    177.800000    105.500000
# max       89.000000    195.590000    186.000000

# %%
df_demo.gender.value_counts()/df_demo.gender.count()
# Out:
# M    0.547858
# F    0.452142
# Name: gender, dtype: float64

# %%
df_demo.ethnicity.value_counts()/df_demo.ethnicity.count()
# Out:
# Caucasian           0.737764
# African American    0.130832
# Other/Unknown       0.057109
# Hispanic            0.044506
# Asian               0.019263
# Native American     0.010527
# Name: ethnicity, dtype: float64

# %%
df_demo.ethnicity.value_counts()
# Out:
# Caucasian           20605
# African American     3654
# Other/Unknown        1595
# Hispanic             1243
# Asian                 538
# Native American       294
# Name: ethnicity, dtype: int64

# %%
df.ethnicity.value_counts()/df.ethnicity.count()
# Out:
# Caucasian           0.779622
# African American    0.108198
# Other/Unknown       0.048697
# Hispanic            0.039270
# Asian               0.017096
# Native American     0.007117
# Name: ethnicity, dtype: float64

# %%
df.ethnicity.value_counts()
# Out:
# Caucasian           100236
# African American     13911
# Other/Unknown         6261
# Hispanic              5049
# Asian                 2198
# Native American        915
# Name: ethnicity, dtype: int64

# %%
#relationship Analysis
#Corralation Matrix

# %%
v_corr = df_vitals.corr()

# %%
plt.figure(figsize=(10, 16))
sns.heatmap(v_corr); #demonstrates some correlation between weight and height

# %%
APACHE_corr = df_APACHE.corr() 
plt.figure(figsize=(10, 16))
sns.heatmap(APACHE_corr); #demonstrates some correlation between weight and height

# %%
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-1a6fe1782b2f> in <module>
# ----> 1 sns.pairplot(df)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1923     # Set up the PairGrid
#    1924     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 1925     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
# ...

# %%
sns.pairplot(df_yes)
